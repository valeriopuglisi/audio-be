# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
from huggingface_hub import ModelSearchArguments, DatasetSearchArguments

model_args = ModelSearchArguments()
dataset_args = DatasetSearchArguments()

# %%
model_args

# %%
model_args.library

# %%
print(model_args.model_name)

# %%
model_args.pipeline_tag
# Out:
# Available Attributes or Keys:
#  * AudioClassification
#  * Audio_to_Audio
#  * AutomaticSpeechRecognition
#  * Conversational
#  * FeatureExtraction
#  * Fill_Mask
#  * ImageClassification
#  * ImageSegmentation
#  * Image_to_Image
#  * Image_to_Text
#  * ObjectDetection
#  * QuestionAnswering
#  * ReinforcementLearning
#  * SentenceSimilarity
#  * Summarization
#  * TableQuestionAnswering
#  * TabularClassification
#  * TabularRegression
#  * Text2TextGeneration (Key only)
#  * TextClassification
#  * TextGeneration
#  * Text_to_Image
#  * Text_to_Speech
#  * TokenClassification
#  * Translation
#  * UnconditionalImageGeneration
#  * VisualQuestionAnswering
#  * VoiceActivityDetection
#  * Zero_ShotClassification

# %%
model_args.library.PyTorch

# %%
from huggingface_hub import ModelFilter, DatasetFilter

filt = ModelFilter(
    task=model_args.pipeline_tag.AutomaticSpeechRecognition, 
    library=[model_args.library.PyTorch, model_args.library.TensorFlow]
)
api.list_models(filter=filt)

# %%
from huggingface_hub import ModelFilter, DatasetFilter

filt = ModelFilter(
    task=model_args.pipeline_tag.AudioClassification,
)
api.list_models(filter=filt)
Conversational

# %%
from huggingface_hub import ModelFilter, DatasetFilter

filt = ModelFilter(
    task=model_args.pipeline_tag.VoiceActivityDetection,
)
api.list_models(filter=filt)

# %%
from huggingface_hub import ModelFilter, DatasetFilter

filt = ModelFilter(
    task=model_args.pipeline_tag.Conversational,
)
api.list_models(filter=filt)

# %%
from huggingface_hub import ModelFilter, DatasetFilter

filt = ModelFilter(
    task=model_args.pipeline_tag.Audio_to_Audio,
)
api.list_models(filter=filt)

# %%
from huggingface_hub import ModelFilter, DatasetFilter

filt = ModelFilter(
    task=model_args.pipeline_tag.Audio_to_Audio,
)
api.list_models(filter=filt)

# %%
from huggingface_hub import ModelFilter, DatasetFilter

filt = ModelFilter(
    task=model_args.pipeline_tag.Translation,
)
api.list_models(filter=filt)
# Out:
# [ModelInfo: {
#  	modelId: t5-small
#  	sha: d78aea13fa7ecd06c29e3e46195d6341255065d5
#  	lastModified: 2022-07-22T08:11:14.000Z
#  	tags: ['pytorch', 'tf', 'jax', 'rust', 't5', 'text2text-generation', 'en', 'fr', 'ro', 'de', 'dataset:c4', 'arxiv:1805.12471', 'arxiv:1708.00055', 'arxiv:1704.05426', 'arxiv:1606.05250', 'arxiv:1808.09121', 'arxiv:1810.12885', 'arxiv:1905.10044', 'arxiv:1910.09700', 'transformers', 'summarization', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='spiece.model'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: None
#  	config: None
#  	id: t5-small
#  	downloads: 1877214
#  	likes: 20
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: t5-base
#  	sha: 23aa4f41cb7c08d4b05c8f327b22bfa0eb8c7ad9
#  	lastModified: 2022-07-22T08:10:56.000Z
#  	tags: ['pytorch', 'tf', 'jax', 'rust', 't5', 'text2text-generation', 'en', 'fr', 'ro', 'de', 'dataset:c4', 'arxiv:1805.12471', 'arxiv:1708.00055', 'arxiv:1704.05426', 'arxiv:1606.05250', 'arxiv:1808.09121', 'arxiv:1810.12885', 'arxiv:1905.10044', 'arxiv:1910.09700', 'transformers', 'summarization', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='spiece.model'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: None
#  	config: None
#  	id: t5-base
#  	downloads: 1639992
#  	likes: 53
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: t5-large
#  	sha: cb7a9673bcaf9ab8b677ad4a5650c1d74b4a5a8e
#  	lastModified: 2022-07-22T08:11:26.000Z
#  	tags: ['pytorch', 'tf', 'jax', 't5', 'text2text-generation', 'en', 'fr', 'ro', 'de', 'dataset:c4', 'arxiv:1805.12471', 'arxiv:1708.00055', 'arxiv:1704.05426', 'arxiv:1606.05250', 'arxiv:1808.09121', 'arxiv:1810.12885', 'arxiv:1905.10044', 'arxiv:1910.09700', 'transformers', 'summarization', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='spiece.model'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: None
#  	config: None
#  	id: t5-large
#  	downloads: 382810
#  	likes: 16
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-fr-en
#  	sha: 967b0840416a86ccf02573c8fedf9dd0e0b42fd6
#  	lastModified: 2021-09-09T21:53:38.000Z
#  	tags: ['pytorch', 'jax', 'marian', 'text2text-generation', 'fr', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-fr-en
#  	downloads: 358127
#  	likes: 5
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-zh-en
#  	sha: 6b02b2132d97136ebed2851703f2b3407ea9cf47
#  	lastModified: 2022-07-14T08:52:32.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'zh', 'en', 'transformers', 'translation', 'license:cc-by-4.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-zh-en
#  	downloads: 325859
#  	likes: 32
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-mul-en
#  	sha: bc0ba94fb12f8b8cf88bd8a925b15ccd5fb94340
#  	lastModified: 2020-08-21T14:42:48.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'ca', 'es', 'os', 'eo', 'ro', 'fy', 'cy', 'is', 'lb', 'su', 'an', 'sq', 'fr', 'ht', 'rm', 'cv', 'ig', 'am', 'eu', 'tr', 'ps', 'af', 'ny', 'ch', 'uk', 'sl', 'lt', 'tk', 'sg', 'ar', 'lg', 'bg', 'be', 'ka', 'gd', 'ja', 'si', 'br', 'mh', 'km', 'th', 'ty', 'rw', 'te', 'mk', 'or', 'wo', 'kl', 'mr', 'ru', 'yo', 'hu', 'fo', 'zh', 'ti', 'co', 'ee', 'oc', 'sn', 'mt', 'ts', 'pl', 'gl', 'nb', 'bn', 'tt', 'bo', 'lo', 'id', 'gn', 'nv', 'hy', 'kn', 'to', 'io', 'so', 'vi', 'da', 'fj', 'gv', 'sm', 'nl', 'mi', 'pt', 'hi', 'se', 'as', 'ta', 'et', 'kw', 'ga', 'sv', 'ln', 'na', 'mn', 'gu', 'wa', 'lv', 'jv', 'el', 'my', 'ba', 'it', 'hr', 'ur', 'ce', 'nn', 'fi', 'mg', 'rn', 'xh', 'ab', 'de', 'cs', 'he', 'zu', 'yi', 'ml', 'mul', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-mul-en
#  	downloads: 323430
#  	likes: 8
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-es-en
#  	sha: 7709af724cf305012a250cbd13cf3bfdbd2b66b0
#  	lastModified: 2021-01-18T08:23:34.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'es', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-es-en
#  	downloads: 304944
#  	likes: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-de
#  	sha: 61a2efe1dd1ca51242d9df09a1a0634b17046125
#  	lastModified: 2022-07-14T08:57:07.000Z
#  	tags: ['pytorch', 'tf', 'jax', 'rust', 'marian', 'text2text-generation', 'en', 'de', 'transformers', 'translation', 'license:cc-by-4.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-de
#  	downloads: 242210
#  	likes: 5
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-ROMANCE
#  	sha: 92870a2f094c444064c7a568c25eef6971e07b03
#  	lastModified: 2021-09-09T21:34:01.000Z
#  	tags: ['pytorch', 'tf', 'jax', 'rust', 'marian', 'text2text-generation', 'en', 'roa', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-ROMANCE
#  	downloads: 166457
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: t5-11b
#  	sha: 41f839df070947ed9275dedaf3d28c75fb4d43e8
#  	lastModified: 2022-07-22T08:11:37.000Z
#  	tags: ['pytorch', 'tf', 't5', 'text2text-generation', 'en', 'fr', 'ro', 'de', 'dataset:c4', 'arxiv:1805.12471', 'arxiv:1708.00055', 'arxiv:1704.05426', 'arxiv:1606.05250', 'arxiv:1808.09121', 'arxiv:1810.12885', 'arxiv:1905.10044', 'arxiv:1910.09700', 'transformers', 'summarization', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='spiece.model'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: None
#  	config: None
#  	id: t5-11b
#  	downloads: 153351
#  	likes: 5
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-de-en
#  	sha: 6137149949ac01d19d8eeef6e35d32221dabc8e4
#  	lastModified: 2021-09-09T21:30:51.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'de', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-de-en
#  	downloads: 137982
#  	likes: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-roa-en
#  	sha: 7d547ac627a5bee2cbeb5e614f9752927eb52aab
#  	lastModified: 2020-08-21T14:42:49.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'it', 'ca', 'rm', 'es', 'ro', 'gl', 'co', 'wa', 'pt', 'oc', 'an', 'id', 'fr', 'ht', 'roa', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-roa-en
#  	downloads: 122592
#  	likes: 1
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-ru-en
#  	sha: a06887d8d700245d4b10a20b6d89c1ad778f33c2
#  	lastModified: 2022-07-14T08:56:05.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'ru', 'en', 'transformers', 'translation', 'license:cc-by-4.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-ru-en
#  	downloads: 111169
#  	likes: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: facebook/mbart-large-en-ro
#  	sha: 2534e987b9ed03c416bbbaefa1a39e3441439bdd
#  	lastModified: 2021-03-10T03:46:29.000Z
#  	tags: ['pytorch', 'tf', 'mbart', 'en', 'ro', 'transformers', 'translation', 'license:mit']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='sentence.bpe.model'), RepoFile(rfilename='sentencepiece.bpe.model'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: facebook
#  	config: None
#  	id: facebook/mbart-large-en-ro
#  	downloads: 84815
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-ja-en
#  	sha: 6282eb0555cd0253dc9fac00c5fafb2825ad04b4
#  	lastModified: 2021-09-10T13:53:12.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'ja', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-ja-en
#  	downloads: 83215
#  	likes: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-fr
#  	sha: a8fbc1c711cb6263e8a20c5229b210cc05c57ff0
#  	lastModified: 2021-09-09T21:35:24.000Z
#  	tags: ['pytorch', 'jax', 'marian', 'text2text-generation', 'en', 'fr', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-fr
#  	downloads: 81286
#  	likes: 3
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-es
#  	sha: c8b63c83f30e46417ce423a585f9b9e20e1b877d
#  	lastModified: 2021-07-13T16:24:56.000Z
#  	tags: ['pytorch', 'jax', 'marian', 'text2text-generation', 'en', 'es', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-es
#  	downloads: 78814
#  	likes: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-ROMANCE-en
#  	sha: dd27a5df7623594b19ab50244084e2beddc2181c
#  	lastModified: 2021-09-09T21:25:31.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'roa', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-ROMANCE-en
#  	downloads: 76740
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-zh
#  	sha: 93db7712e4698309ac17a80605adbf54dea5c8ee
#  	lastModified: 2021-09-09T21:40:41.000Z
#  	tags: ['pytorch', 'tf', 'jax', 'rust', 'marian', 'text2text-generation', 'en', 'zh', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-zh
#  	downloads: 71898
#  	likes: 20
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-ar-en
#  	sha: 9c5efffe6f69dcb65d7156f40dfa27b54be34258
#  	lastModified: 2021-09-09T21:26:15.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'ar', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-ar-en
#  	downloads: 65259
#  	likes: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: t5-3b
#  	sha: 7a91dcdb0494b6d21c9aec758dac1f33c8db715c
#  	lastModified: 2022-07-22T08:11:47.000Z
#  	tags: ['pytorch', 'tf', 't5', 'text2text-generation', 'en', 'fr', 'ro', 'de', 'dataset:c4', 'arxiv:1805.12471', 'arxiv:1708.00055', 'arxiv:1704.05426', 'arxiv:1606.05250', 'arxiv:1808.09121', 'arxiv:1810.12885', 'arxiv:1905.10044', 'arxiv:1910.09700', 'transformers', 'summarization', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='spiece.model'), RepoFile(rfilename='tf_model.h5'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: None
#  	config: None
#  	id: t5-3b
#  	downloads: 64450
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-nl-en
#  	sha: 642ab6dc2d08ca9b5706ff44191dc443eae738e1
#  	lastModified: 2021-09-10T13:59:07.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'nl', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-nl-en
#  	downloads: 57717
#  	likes: 4
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-ko-en
#  	sha: 8bf548f19accb8fdc96055608840f5a0c194ec8d
#  	lastModified: 2020-08-21T14:42:47.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'ko', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-ko-en
#  	downloads: 45186
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: facebook/mbart-large-cc25
#  	sha: 2df0e6dd8a0e7f6df056fe4d0d95941a04b64e4f
#  	lastModified: 2021-03-10T03:48:19.000Z
#  	tags: ['pytorch', 'mbart', 'text2text-generation', 'en', 'ar', 'cs', 'de', 'et', 'fi', 'fr', 'gu', 'hi', 'it', 'ja', 'kk', 'ko', 'lt', 'lv', 'my', 'ne', 'nl', 'ro', 'ru', 'si', 'tr', 'vi', 'zh', 'multilingual', 'transformers', 'translation', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='sentence.bpe.model'), RepoFile(rfilename='sentencepiece.bpe.model'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: facebook
#  	config: None
#  	id: facebook/mbart-large-cc25
#  	downloads: 39272
#  	likes: 16
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-fi-en
#  	sha: 7fb1e75696c8b8930df5afae6bb5d22ffca4ed30
#  	lastModified: 2021-01-18T08:32:43.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'fi', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-fi-en
#  	downloads: 38777
#  	likes: 1
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-it
#  	sha: 4c56f4ddc9fcfccec7799f5cef4d90f7c99dd658
#  	lastModified: 2021-09-09T21:36:26.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'en', 'it', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-it
#  	downloads: 37315
#  	likes: 3
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-sv-en
#  	sha: e4f28e50a1614873bbe8d16d3c48b52e37778ead
#  	lastModified: 2021-09-10T14:06:11.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'sv', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-sv-en
#  	downloads: 32330
#  	likes: 3
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-ru
#  	sha: b4544f727b37dc7b186fa5d5a99baa74cd2f4128
#  	lastModified: 2021-09-09T21:38:48.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'en', 'ru', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-ru
#  	downloads: 28644
#  	likes: 3
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-it-en
#  	sha: 23f2c7f29233a3e0accc900625d65ddf6a49b93e
#  	lastModified: 2021-09-10T13:52:52.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'it', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-it-en
#  	downloads: 27785
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-pl-en
#  	sha: 361ac28538863fafa2090bf91c36d02b9c596d5b
#  	lastModified: 2021-09-10T14:01:16.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'pl', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-pl-en
#  	downloads: 26000
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-id-en
#  	sha: cbdb70ef26d3c5a6585e6a810da1003bd50bb6b3
#  	lastModified: 2021-09-09T22:11:11.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'id', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-id-en
#  	downloads: 20865
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-da-en
#  	sha: 8971eb3839ec41bddd060128b9b83038bb43fd96
#  	lastModified: 2021-09-09T21:29:52.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'da', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-da-en
#  	downloads: 16810
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: facebook/wmt19-ru-en
#  	sha: d145f3063a3e25e43c04c9aa64de38999b3fb2cd
#  	lastModified: 2020-12-11T21:40:01.000Z
#  	tags: ['pytorch', 'fsmt', 'text2text-generation', 'ru', 'en', 'dataset:wmt19', 'arxiv:1907.06616', 'transformers', 'translation', 'wmt19', 'facebook', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='merges.txt'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab-src.json'), RepoFile(rfilename='vocab-tgt.json')]
#  	private: False
#  	author: facebook
#  	config: None
#  	id: facebook/wmt19-ru-en
#  	downloads: 16409
#  	likes: 3
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-et-en
#  	sha: 3649f4761e2a1b25f2c19e3f1732c6ba9ef61519
#  	lastModified: 2021-09-09T21:46:01.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'et', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-et-en
#  	downloads: 14926
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-bat-en
#  	sha: 760a39c69d5158182c320e47986306e24e96fa1f
#  	lastModified: 2021-01-18T07:48:50.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'lt', 'lv', 'bat', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-bat-en
#  	downloads: 11835
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-uk-ru
#  	sha: 0dbf7d9872d43f0599f41259b927e012f84b87fe
#  	lastModified: 2020-08-21T14:42:51.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'uk', 'ru', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-uk-ru
#  	downloads: 11634
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-nl
#  	sha: cd888e7c566d69f91f675d7a12d26613d1c4d826
#  	lastModified: 2021-09-09T21:38:05.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'en', 'nl', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-nl
#  	downloads: 10960
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-hi-en
#  	sha: 48acb8543e96768bc9fea5b3813d0e46fe1a45f3
#  	lastModified: 2021-09-09T22:09:54.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'hi', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-hi-en
#  	downloads: 9308
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: facebook/wmt19-en-de
#  	sha: b33976783993b11baabc19313275865ee87931e3
#  	lastModified: 2020-12-11T21:39:55.000Z
#  	tags: ['pytorch', 'fsmt', 'text2text-generation', 'en', 'de', 'dataset:wmt19', 'arxiv:1907.06616', 'transformers', 'translation', 'wmt19', 'facebook', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='merges.txt'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab-src.json'), RepoFile(rfilename='vocab-tgt.json')]
#  	private: False
#  	author: facebook
#  	config: None
#  	id: facebook/wmt19-en-de
#  	downloads: 9278
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: optimum/t5-small
#  	sha: 20d146343f7cd75161d29a6fd225d75f8bb3b04f
#  	lastModified: 2022-06-29T13:25:52.000Z
#  	tags: ['onnx', 't5', 'text2text-generation', 'en', 'fr', 'ro', 'de', 'dataset:c4', 'arxiv:1910.10683', 'transformers', 'summarization', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='decoder_model.onnx'), RepoFile(rfilename='decoder_with_past_model.onnx'), RepoFile(rfilename='encoder_model.onnx'), RepoFile(rfilename='tokenizer.json')]
#  	private: False
#  	author: optimum
#  	config: None
#  	id: optimum/t5-small
#  	downloads: 9247
#  	likes: 0
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: facebook/wmt19-de-en
#  	sha: 80d366f635721148ffa2a0a58591cb672c9b4982
#  	lastModified: 2020-12-11T21:39:51.000Z
#  	tags: ['pytorch', 'fsmt', 'text2text-generation', 'de', 'en', 'dataset:wmt19', 'arxiv:1907.06616', 'transformers', 'translation', 'wmt19', 'facebook', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='merges.txt'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab-src.json'), RepoFile(rfilename='vocab-tgt.json')]
#  	private: False
#  	author: facebook
#  	config: None
#  	id: facebook/wmt19-de-en
#  	downloads: 8177
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-tr-en
#  	sha: 3252b40d8b9dead8012364425fd00db1a26abf85
#  	lastModified: 2021-09-11T10:49:35.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'tr', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-tr-en
#  	downloads: 7384
#  	likes: 9
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-tc-big-en-pt
#  	sha: 6cd179c3a36b2aa259d58bc8c0dc33af3d8e4632
#  	lastModified: 2022-06-01T13:03:26.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'en', 'pt', 'pt_br', 'transformers', 'translation', 'opus-mt-tc', 'license:cc-by-4.0', 'model-index', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='benchmark_results.txt'), RepoFile(rfilename='benchmark_translations.zip'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='special_tokens_map.json'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-tc-big-en-pt
#  	downloads: 7284
#  	likes: 1
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-uk-en
#  	sha: d6c1e62ab5c03e34a3d118382be7a27b704241f0
#  	lastModified: 2021-09-11T10:51:14.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'uk', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-uk-en
#  	downloads: 6516
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-lv-en
#  	sha: 3b019339e88ac4f79044be45cfa75ff5fedbceea
#  	lastModified: 2021-09-10T13:57:07.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'lv', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-lv-en
#  	downloads: 6069
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-ar
#  	sha: 12f7bc254b7e475b6377f440d488063d7fb51571
#  	lastModified: 2021-02-28T14:15:11.000Z
#  	tags: ['pytorch', 'rust', 'marian', 'text2text-generation', 'en', 'ar', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='rust_model.ot'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-ar
#  	downloads: 5981
#  	likes: 5
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-ca-en
#  	sha: 22113f5e0e8e89677d6e0142e55c85402eecb455
#  	lastModified: 2021-09-09T21:28:18.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'ca', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-ca-en
#  	downloads: 4974
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-gmq-en
#  	sha: 74efbe7477ba9acf0bcc143fcad9f5280db2fab4
#  	lastModified: 2021-01-18T08:52:51.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'da', 'nb', 'sv', 'is', 'nn', 'fo', 'gmq', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-gmq-en
#  	downloads: 4916
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-cs
#  	sha: 7cba4a7e3daff13c48fc2fcd740ef0711b1dd075
#  	lastModified: 2021-09-09T21:34:42.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'en', 'cs', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-cs
#  	downloads: 4867
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-ro
#  	sha: 6d32771161c298fb3164c208e48fea050a85ab65
#  	lastModified: 2021-09-09T21:38:44.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'en', 'ro', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-ro
#  	downloads: 4626
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-fi
#  	sha: 627fe90df5c335be61521cd89c68f62e2bdce050
#  	lastModified: 2021-09-09T21:35:17.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'en', 'fi', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-fi
#  	downloads: 4585
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-cs-en
#  	sha: 186ab5dff3e18ca970a492525c0ca4b398d525ab
#  	lastModified: 2021-09-09T21:29:22.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'cs', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-cs-en
#  	downloads: 4065
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: salesken/translation-hi-en
#  	sha: 3ee83d07285c37a8da5858e5e90f30e958fb0240
#  	lastModified: 2021-07-01T09:30:25.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'hi', 'transformers', 'translation', 'salesken', 'opus-mt', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='special_tokens_map.json'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: salesken
#  	config: None
#  	id: salesken/translation-hi-en
#  	downloads: 4031
#  	likes: 1
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-hu-en
#  	sha: 62599d9d6eca96022d26974486779623f09ebc9c
#  	lastModified: 2021-09-09T22:10:51.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'hu', 'en', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-hu-en
#  	downloads: 3920
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-en-da
#  	sha: 9786126ba34f1f86636af779ef13557bd9d1b246
#  	lastModified: 2021-09-09T21:34:51.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'en', 'da', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-en-da
#  	downloads: 3911
#  	likes: 1
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: staka/fugumt-en-ja
#  	sha: bf625f6aa260d78f000ab096ab7782ed4acb1770
#  	lastModified: 2022-05-29T08:27:41.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'en', 'ja', 'transformers', 'translation', 'license:cc-by-sa-4.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='special_tokens_map.json'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: staka
#  	config: None
#  	id: staka/fugumt-en-ja
#  	downloads: 3826
#  	likes: 2
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: unicamp-dl/translation-en-pt-t5
#  	sha: 8418d7e9b1837687137af06624cb3596b45c9343
#  	lastModified: 2021-10-11T03:47:21.000Z
#  	tags: ['pytorch', 't5', 'text2text-generation', 'en', 'pt', 'dataset:EMEA', 'dataset:ParaCrawl 99k', 'dataset:CAPES', 'dataset:Scielo', 'dataset:JRC-Acquis', 'dataset:Biomedical Domain Corpora', 'transformers', 'translation', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='special_tokens_map.json'), RepoFile(rfilename='spiece.model'), RepoFile(rfilename='tokenizer.json'), RepoFile(rfilename='tokenizer_config.json')]
#  	private: False
#  	author: unicamp-dl
#  	config: None
#  	id: unicamp-dl/translation-en-pt-t5
#  	downloads: 3761
#  	likes: 5
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: facebook/wmt19-en-ru
#  	sha: a96448f0cef6a0b22c8f73f6f0e74b610efe806f
#  	lastModified: 2020-12-11T21:39:58.000Z
#  	tags: ['pytorch', 'fsmt', 'text2text-generation', 'en', 'ru', 'dataset:wmt19', 'arxiv:1907.06616', 'transformers', 'translation', 'wmt19', 'facebook', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
# ...
#  	sha: 17f3e9461db05569f8160c3a1e14da7a3a81c84e
#  	lastModified: 2020-08-21T14:42:51.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'uk', 'hu', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-uk-hu
#  	downloads: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-uk-sv
#  	sha: ccd53b0c75d1dc9367f29121202a0a8df67fae03
#  	lastModified: 2021-09-11T10:51:29.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'uk', 'sv', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-uk-sv
#  	downloads: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-wls-sv
#  	sha: 012ca81a2882b73e06e7f552611d28a7bcfe1bcf
#  	lastModified: 2021-09-11T10:52:16.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'wls', 'sv', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-wls-sv
#  	downloads: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-yo-fi
#  	sha: 82b100a0d8c4e8ca07f63a325b68032af8abd99b
#  	lastModified: 2021-09-11T10:52:53.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'yo', 'fi', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-yo-fi
#  	downloads: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: NYTK/translation-bart-en-hu
#  	sha: 879ebeb975a3226c2336501fbda338b2095ecd9f
#  	lastModified: 2022-02-14T13:28:40.000Z
#  	tags: ['pytorch', 'bart', 'text2text-generation', 'en', 'hu', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='merges.txt'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='special_tokens_map.json'), RepoFile(rfilename='tokenizer.json'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: NYTK
#  	config: None
#  	id: NYTK/translation-bart-en-hu
#  	downloads: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: lighteternal/SSE-TUC-mt-el-en-lowercase
#  	sha: 043dffcf265eb5362f13231e9ea9757def46bda8
#  	lastModified: 2021-03-31T17:26:44.000Z
#  	tags: ['pytorch', 'fsmt', 'text2text-generation', 'en', 'el', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='merges.txt'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab-src.json'), RepoFile(rfilename='vocab-tgt.json')]
#  	private: False
#  	author: lighteternal
#  	config: None
#  	id: lighteternal/SSE-TUC-mt-el-en-lowercase
#  	downloads: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: pere/nb-nn-dev
#  	sha: 583865f7e462cb2f43db3ecb339ffc94f87d4c00
#  	lastModified: 2021-09-28T07:34:18.000Z
#  	tags: ['pytorch', 'jax', 'tensorboard', 'no', 'dataset:oscar', 'translation', 'license:cc-by-4.0']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='bart-base-xsum/events.out.tfevents.1630834902.t1v-n-1a0a7c50-w-0.2860338.3.v2'), RepoFile(rfilename='config.json'), RepoFile(rfilename='counttokens.py'), RepoFile(rfilename='events.out.tfevents.1631775171.t1v-n-6f5efcd5-w-0.496905.0.v2'), RepoFile(rfilename='events.out.tfevents.1631780323.t1v-n-6f5efcd5-w-0.503576.0.v2'), RepoFile(rfilename='events.out.tfevents.1631781584.t1v-n-6f5efcd5-w-0.506272.0.v2'), RepoFile(rfilename='events.out.tfevents.1631784985.t1v-n-6f5efcd5-w-0.511048.0.v2'), RepoFile(rfilename='events.out.tfevents.1631801125.t1v-n-6f5efcd5-w-0.528282.0.v2'), RepoFile(rfilename='events.out.tfevents.1631863067.t1v-n-6f5efcd5-w-0.588691.0.v2'), RepoFile(rfilename='events.out.tfevents.1631871619.t1v-n-6f5efcd5-w-0.598477.0.v2'), RepoFile(rfilename='events.out.tfevents.1631886911.t1v-n-6f5efcd5-w-0.614917.0.v2'), RepoFile(rfilename='events.out.tfevents.1631895055.t1v-n-6f5efcd5-w-0.624181.0.v2'), RepoFile(rfilename='events.out.tfevents.1631902866.t1v-n-6f5efcd5-w-0.634039.0.v2'), RepoFile(rfilename='events.out.tfevents.1631910322.t1v-n-6f5efcd5-w-0.642801.0.v2'), RepoFile(rfilename='events.out.tfevents.1631911348.t1v-n-6f5efcd5-w-0.645034.0.v2'), RepoFile(rfilename='events.out.tfevents.1631914282.t1v-n-6f5efcd5-w-0.649047.0.v2'), RepoFile(rfilename='events.out.tfevents.1631953849.t1v-n-6f5efcd5-w-0.685100.0.v2'), RepoFile(rfilename='events.out.tfevents.1631965058.t1v-n-6f5efcd5-w-0.697498.0.v2'), RepoFile(rfilename='events.out.tfevents.1632002529.t1v-n-6f5efcd5-w-0.734274.0.v2'), RepoFile(rfilename='events.out.tfevents.1632041827.t1v-n-6f5efcd5-w-0.772839.0.v2'), RepoFile(rfilename='events.out.tfevents.1632079497.t1v-n-6f5efcd5-w-0.809987.0.v2'), RepoFile(rfilename='events.out.tfevents.1632249176.t1v-n-6f5efcd5-w-0.977090.0.v2'), RepoFile(rfilename='events.out.tfevents.1632254357.t1v-n-6f5efcd5-w-0.983770.0.v2'), RepoFile(rfilename='events.out.tfevents.1632323513.t1v-n-6f5efcd5-w-0.1054042.0.v2'), RepoFile(rfilename='events.out.tfevents.1632324935.t1v-n-6f5efcd5-w-0.1056940.0.v2'), RepoFile(rfilename='events.out.tfevents.1632326100.t1v-n-6f5efcd5-w-0.1060663.0.v2'), RepoFile(rfilename='events.out.tfevents.1632326914.t1v-n-6f5efcd5-w-0.1063031.0.v2'), RepoFile(rfilename='events.out.tfevents.1632327692.t1v-n-6f5efcd5-w-0.1065247.0.v2'), RepoFile(rfilename='events.out.tfevents.1632335569.t1v-n-6f5efcd5-w-0.1074637.0.v2'), RepoFile(rfilename='events.out.tfevents.1632341246.t1v-n-6f5efcd5-w-0.1081795.0.v2'), RepoFile(rfilename='events.out.tfevents.1632374390.t1v-n-6f5efcd5-w-0.1114186.0.v2'), RepoFile(rfilename='events.out.tfevents.1632377409.t1v-n-6f5efcd5-w-0.1118545.0.v2'), RepoFile(rfilename='events.out.tfevents.1632387160.t1v-n-6f5efcd5-w-0.1129689.0.v2'), RepoFile(rfilename='events.out.tfevents.1632401484.t1v-n-6f5efcd5-w-0.1144797.0.v2'), RepoFile(rfilename='events.out.tfevents.1632429250.t1v-n-6f5efcd5-w-0.14808.0.v2'), RepoFile(rfilename='events.out.tfevents.1632429327.t1v-n-6f5efcd5-w-0.16419.0.v2'), RepoFile(rfilename='events.out.tfevents.1632512424.t1v-n-6f5efcd5-w-0.105206.0.v2'), RepoFile(rfilename='events.out.tfevents.1632530445.t1v-n-6f5efcd5-w-0.124013.0.v2'), RepoFile(rfilename='events.out.tfevents.1632564069.t1v-n-6f5efcd5-w-0.157935.0.v2'), RepoFile(rfilename='events.out.tfevents.1632640609.t1v-n-6f5efcd5-w-0.234121.0.v2'), RepoFile(rfilename='events.out.tfevents.1632686606.t1v-n-6f5efcd5-w-0.279871.0.v2'), RepoFile(rfilename='events.out.tfevents.1632764374.t1v-n-6f5efcd5-w-0.356044.0.v2'), RepoFile(rfilename='events.out.tfevents.1632807175.t1v-n-6f5efcd5-w-0.398941.0.v2'), RepoFile(rfilename='flax_model.msgpack'), RepoFile(rfilename='nb_nn_nb.json'), RepoFile(rfilename='nor-mt5-flax_model.msgpack'), RepoFile(rfilename='npk_dev.json'), RepoFile(rfilename='npk_test.json'), RepoFile(rfilename='npk_train.json'), RepoFile(rfilename='parallel_dev.json'), RepoFile(rfilename='parallel_src_tgt_dev.json'), Rep ...
#  	private: False
#  	author: pere
#  	config: None
#  	id: pere/nb-nn-dev
#  	downloads: 7
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-tc-base-uk-hu
#  	sha: 318e13e415ffc255e7fdfce3d4236b7fa26f0a25
#  	lastModified: 2022-06-01T13:10:31.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'hu', 'uk', 'transformers', 'translation', 'opus-mt-tc', 'license:cc-by-4.0', 'model-index', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='benchmark_results.txt'), RepoFile(rfilename='benchmark_translations.zip'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='special_tokens_map.json'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-tc-base-uk-hu
#  	downloads: 7
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-bcl-de
#  	sha: 526eb0407d3feeccb096471b117e406d624aab42
#  	lastModified: 2021-09-09T21:26:41.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'bcl', 'de', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-bcl-de
#  	downloads: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-bem-es
#  	sha: ba91f9b554425480027fc8ebb7ecd9474362e50b
#  	lastModified: 2021-09-09T21:27:07.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'bem', 'es', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-bem-es
#  	downloads: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-bem-sv
#  	sha: 4d5053100ff89142b1fd9b4a86c0b204c78934a9
#  	lastModified: 2021-09-09T21:27:18.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'bem', 'sv', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-bem-sv
#  	downloads: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-ber-fr
#  	sha: 3b231ec4923f2342a1c3a382086846783a4c5f67
#  	lastModified: 2021-09-09T21:27:29.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'ber', 'fr', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-ber-fr
#  	downloads: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-bg-tr
#  	sha: c44ddb80dfc0e353bb5574b1bc937aecdb983281
#  	lastModified: 2021-01-18T07:51:22.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'bg', 'tr', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='metadata.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-bg-tr
#  	downloads: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-bzs-sv
#  	sha: 2a12941aeaeaa78979240cfcb1d63e44958af76f
#  	lastModified: 2021-09-09T21:28:14.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'bzs', 'sv', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-bzs-sv
#  	downloads: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-cs-fi
#  	sha: d60a357cfb2c4d1df38b43f2fafe34dbff0199cf
#  	lastModified: 2021-09-09T21:29:26.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'cs', 'fi', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-cs-fi
#  	downloads: 6
#  	library_name: transformers
#  },
#  ModelInfo: {
#  	modelId: Helsinki-NLP/opus-mt-de-da
#  	sha: bccfbee95d55ba1333fd447f67574453eba5d948
#  	lastModified: 2021-09-09T21:30:32.000Z
#  	tags: ['pytorch', 'marian', 'text2text-generation', 'de', 'da', 'transformers', 'translation', 'license:apache-2.0', 'autotrain_compatible']
#  	pipeline_tag: translation
#  	siblings: [RepoFile(rfilename='.gitattributes'), RepoFile(rfilename='README.md'), RepoFile(rfilename='config.json'), RepoFile(rfilename='pytorch_model.bin'), RepoFile(rfilename='source.spm'), RepoFile(rfilename='target.spm'), RepoFile(rfilename='tokenizer_config.json'), RepoFile(rfilename='vocab.json')]
#  	private: False
#  	author: Helsinki-NLP
#  	config: None
#  	id: Helsinki-NLP/opus-mt-de-da
#  	downloads: 6
#  	library_name: transformers
#  },
#  ...]
